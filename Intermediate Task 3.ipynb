# %%
import pandas as pd

# %%
path="./Cleaned_dataset.csv"

# %%
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0  Employee ID  Age  Gender  Years at Company  Job Role  \
# 0           0         8410   31       1                19         0
# 1           1        64756   59       0                 4         3
# 2           2        30257   24       0                10         2
# 3           3        65791   36       0                 7         0
# 4           4        65026   56       1                41         0
#
#    Monthly Income  Work-Life Balance  Job Satisfaction  Performance Rating  \
# 0            5390                  0                 2                   0
# 1            5534                  3                 0                   3
# 2            8159                  2                 0                   3
# 3            3989                  2                 0                   2
# 4            4821                  1                 3                   0
#
#    ...  Number of Dependents  Job Level  Company Size  \
# 0  ...                     0          1             1
# 1  ...                     3          1             1
# 2  ...                     3          1             1
# 3  ...                     2          1             2
# 4  ...                     0          2             1
#
#    Company Tenure (In Months)  Remote Work  Leadership Opportunities  \
# 0                        89.0            0                         0
# 1                        21.0            0                         0
# 2                        74.0            0                         0
# 3                        50.0            1                         0
# 4                        68.0            0                         0
#
#    Innovation Opportunities  Company Reputation  Employee Recognition  \
# 0                         0                   0                     2
# 1                         0                   1                     1
# 2                         0                   3                     1
# 3                         0                   2                     2
# 4                         0                   1                     2
#
#    Attrition
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#
# [5 rows x 25 columns]

# %%
df.drop(columns=['Unnamed: 0','Employee ID'],axis=1)
# Out:
#        Age  Gender  Years at Company  Job Role  Monthly Income  \
# 0       31       1                19         0            5390
# 1       59       0                 4         3            5534
# 2       24       0                10         2            8159
# 3       36       0                 7         0            3989
# 4       56       1                41         0            4821
# ...    ...     ...               ...       ...             ...
# 74605   44       0                20         2            7578
# 74606   45       1                26         4            8342
# 74607   28       0                 3         4            9763
# 74608   37       1                 3         0            3644
# 74609   38       1                28         3            6172
#
#        Work-Life Balance  Job Satisfaction  Performance Rating  \
# 0                      0                 2                   0
# 1                      3                 0                   3
# 2                      2                 0                   3
# 3                      2                 0                   2
# 4                      1                 3                   0
# ...                  ...               ...                 ...
# 74605                  1                 2                   3
# 74606                  0                 3                   1
# 74607                  3                 1                   0
# 74608                  1                 0                   0
# 74609                  2                 0                   2
#
#        Number of Promotions  Overtime  ...  Number of Dependents  Job Level  \
# 0                         2         0  ...                     0          1
# 1                         3         0  ...                     3          1
# 2                         0         0  ...                     3          1
# 3                         1         0  ...                     2          1
# 4                         0         1  ...                     0          2
# ...                     ...       ...  ...                   ...        ...
# 74605                     2         0  ...                     3          1
# 74606                     3         0  ...                     4          1
# 74607                     0         0  ...                     3          2
# 74608                     2         0  ...                     4          0
# 74609                     0         0  ...                     2          1
#
#        Company Size  Company Tenure (In Months)  Remote Work  \
# 0                 1                   89.000000            0
# 1                 1                   21.000000            0
# 2                 1                   74.000000            0
# 3                 2                   50.000000            1
# 4                 1                   68.000000            0
# ...             ...                         ...          ...
# 74605             0                   52.000000            0
# 74606             1                   55.711899            1
# 74607             2                   67.000000            0
# 74608             1                   16.000000            0
# 74609             1                   84.000000            0
#
#        Leadership Opportunities  Innovation Opportunities  Company Reputation  \
# 0                             0                         0                   0
# 1                             0                         0                   1
# 2                             0                         0                   3
# 3                             0                         0                   2
# 4                             0                         0                   1
# ...                         ...                       ...                 ...
# 74605                         0                         0                   1
# 74606                         0                         0                   3
# 74607                         0                         0                   3
# 74608                         0                         0                   0
# 74609                         0                         0                   0
#
#        Employee Recognition  Attrition
# 0                         2          1
# 1                         1          1
# 2                         1          1
# 3                         2          1
# 4                         2          1
# ...                     ...        ...
# 74605                     3          0
# 74606                     0          1
# 74607                     2          0
# 74608                     2          1
# 74609                     1          1
#
# [74610 rows x 23 columns]

# %%
X=df.drop('Attrition',axis=1)
y=df['Attrition']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rf_model.predict(X_test)

# %% [markdown]
# ## classification report

# %%
from sklearn.metrics import classification_report

# Generate and print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.74      0.73      6998
#            1       0.76      0.75      0.76      7924
#
#     accuracy                           0.74     14922
#    macro avg       0.74      0.74      0.74     14922
# weighted avg       0.74      0.74      0.74     14922
